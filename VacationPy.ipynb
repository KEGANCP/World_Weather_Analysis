# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date      Lat       Lng  \
# 0        0            Ancud      CL  2021-10-09 18:52:44 -41.8697  -73.8203
# 1        1        Maryville      US  2021-10-09 18:52:44  35.7565  -83.9705
# 2        2           Hasaki      JP  2021-10-09 18:52:45  35.7333  140.8333
# 3        3  Arraial Do Cabo      BR  2021-10-09 18:52:45 -22.9661  -42.0278
# 4        4      Kloulklubed      PW  2021-10-09 18:52:45   7.0419  134.2556
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     62.13        72           0        8.46
# 1     80.20        74          20        4.00
# 2     66.60        84           9        5.66
# 3     69.76        68          90       12.66
# 4     83.28        76          36       20.67

# %%
# Get data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
# gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Humidity
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
humidity = city_data_df["Humidity"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
clouds = city_data_df["Cloudiness"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Windspeed
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
winds = city_data_df["Wind Speed"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=winds, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country                 Date      Lat       Lng  \
# 1         1     Maryville      US  2021-10-09 18:52:44  35.7565  -83.9705
# 4         4   Kloulklubed      PW  2021-10-09 18:52:45   7.0419  134.2556
# 8         8  Puerto Ayora      EC  2021-10-09 18:52:47  -0.7393  -90.3518
# 10       10   Kuala Lipis      MY  2021-10-09 18:52:47   4.1842  102.0468
# 12       12        Atuona      PF  2021-10-09 18:52:48  -9.8000 -139.0333
# 15       15      Victoria      HK  2021-10-09 18:48:09  22.2855  114.1577
# 24       24         Fukue      JP  2021-10-09 18:52:52  32.6881  128.8419
# 26       26        Avarua      CK  2021-10-09 18:52:53 -21.2078 -159.7750
# 32       32        Mushie      CD  2021-10-09 18:52:55  -3.0167   16.9000
# 35       35        Faanui      PF  2021-10-09 18:52:56 -16.4833 -151.7500
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      80.20        74          20        4.00
# 4      83.28        76          36       20.67
# 8      76.96        78          84        9.91
# 10     75.90        85         100        0.34
# 12     77.97        68          24       18.90
# 15     80.26        93         100       17.00
# 24     77.61        78           1        7.27
# 26     75.25        73          37        5.75
# 32     75.27        93          99        4.52
# 35     77.86        71          17        6.20

# %%
preferred_cities_df.count()
# Out:
# City_ID       177
# City          177
# Country       177
# Date          177
# Lat           177
# Lng           177
# Max Temp      177
# Humidity      177
# Cloudiness    177
# Wind Speed    177
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 1      Maryville      US     80.20  35.7565  -83.9705
# 4    Kloulklubed      PW     83.28   7.0419  134.2556
# 8   Puerto Ayora      EC     76.96  -0.7393  -90.3518
# 10   Kuala Lipis      MY     75.90   4.1842  102.0468
# 12        Atuona      PF     77.97  -9.8000 -139.0333
# 15      Victoria      HK     80.26  22.2855  114.1577
# 24         Fukue      JP     77.61  32.6881  128.8419
# 26        Avarua      CK     75.25 -21.2078 -159.7750
# 32        Mushie      CD     75.27  -3.0167   16.9000
# 35        Faanui      PF     77.86 -16.4833 -151.7500

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAQCx6TZpHst1avs23USrRoWZy8F6EHPmOBroQ6MbNV_1oMipeOemB9W9hqirXblQSobUPDrNPQryNtcPDCbTTolIiJkzHYqjPoLNXmqlMrgzGV4sEEz2K2zTmrbsx7vQVdz3b7PfQPZDMEJVebF86KFmHGSZoxJXY7CuHFBwS9U45Iwuwg1_0gWXRBqfQ3a4fHDjxD4w9RcqqpdcqRKVBKHq7N9lysGVnhvPRRNSgggfOHry7ByFIIkVYz-lIpgSeCze0PX40i-lPcXAzqs7NP9H1_v6PAjYxRYXd0pTinf8H6TMH1Q_IK5rwxzuGq9X2DVyT6w-xlN5Gv1AhqUAQ5yytXZ_CzJ4-kAjsSn-RWc69mBK1uMlufEPtY-F9HkUeuIZe8cFn4TrfeIADHSvkEworyqDl8zoNtTBmFiVZhv4yBdj9QGXHf',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEARTN71RP9yux2tCKc-lATIFSEYxgLUp57R6GPWLqbgKCc6GXXs_MAIjdD5lD152qZCgQb95iKnrB1B_53YfgfiL4u2-hrvqSRQiLus3ICFFgUZVBMUiby5XsudYyhN9SKh-w2dRosBG56l1v9wPPfYG8-9xmMGGjC1ESWbd41MQ__7',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 295,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEDXT5zmzP2p9l8vMPwinXc3s37dGVS5dwtADfTJm0eQfW95D7HnE7ok-AYw7kbWj_noWjlhw3YM7n1UszxHnuMQzEQvUz4iqYI62kt1oCJqG-ExJj7P6mV3uRyvrrnWa8-EqSiU4reOTO7z8_BdvlHtoYWciTnYTZSXLip-wpYyyHJH',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 610,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617653302915,
#       'lng': 2.348020880291502},
#      'southwest': {'lat': 48.85906736970851, 'lng': 2.345322919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEDiXP2cyQTSkwZJ0ZHkvYBXRBLjQUG2ql9z76YwYq_uxWXKPhR-OicidwcIUfcAK4pqPqCGrdsZOTICc_9VtLg8X0QI0FynuF1PlDHaeYMrO5qJc9FmW2AsdkRfqNge7EoTcN7kg9WCu6pqg0ktzwQlmXm__g8Wjau4DQRoAr98L7Sj',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 857,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEBygIRh9opXegA9Qf9kNfozlqdRuQBZsKL1Wo88-FtSLMqekqIqexWme3Y0EAihPbnHD_SQUS0_bo3nrKj7wB5ls88Rr1zbzvR6aU1YQp-piD7C8XeLyYaWBerFxwsDVmmc5fsZ9ZnEDGjgp-nPflvG__PhflLQ_rYBslDcZG7qyWi9',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2230,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.86165553029149,
#       'lng': 2.345549080291502},
#      'southwest': {'lat': 48.8589575697085, 'lng': 2.342851119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEBH9yiPc0p-Xv_G3eXAFRRBQ9xRwqs843L7dOzZf35dgdhx1zRdJotN5tKaYfJIYjcWEKn3jmFhq46KZ7JwesV404LyJYfC20lqn4frp2fXAATO2ajXYWwlDnRZBxSMCvkIcI32VUYmB3FBBeN24Qd7Y8jOZDvsGQIMpQw2RXC6berI',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 279,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEDuxBv2njpUfhyXQhvnWkTR_GuwfdAU-eWyEDaFdQYYehvA7OWRmcYC4y9nJzJxxe8hnaQbfGJi4rsiJylg4jwZVR9bpQ-54M6oaLADQXaGCj5b6rhcBbWVJGKBCyTflpX2IN_Of7fn1O63f5T-Yld-PsUctG10Jw7y6_MUngn2IS-a',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 701,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8663519, 'lng': 2.3606461},
#     'viewport': {'northeast': {'lat': 48.86775308029149,
#       'lng': 2.361905130291502},
#      'southwest': {'lat': 48.8650551197085, 'lng': 2.359207169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uECWhhzGrByAivW6KnjQSfn2p49x0AfV0IhxXyVx5RR8eoBPhYSajED7fpeWqwIpu6BpBfCfHzBmaKvzwQogaeQu3x62L14dw0TlK35hJuydGYjADkRyrLVJMrMg0_gO3WJQXH-A66_5ymIApf_rnKepIwvXINIsJ-SHgisCTu0zbP7u',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 383,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEDmGUO8YxkK7DDcVLXMTWUDPcH8Z8HgtLj6t5TqJ7_haX21vPdHfx8lDXSsjK2Lx0Pt_bWIAdM0zmFgdF8C-snJDd8lRIS7TPKb12WUI9G8UHlHOGrbZy9gaffBH1TVCmaE9k78TivVv7F6rkFaDe9gLCtDgnNd2GzslRIM8wdOGWrx',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.4,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 508,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin Nguyen</a>'],
#      'photo_reference': 'Aap_uEC0fvdaa0tx6Dxg4vIPuwwNy2-zwzxXflS106f75Heje793wGAjTGaoKgclbBCIzYGjoedG-XORYJG4eKlBqQzUHTY3NUmg068p3ZDlOUk3YwC8l2LNkNFXUoO03rUhFg-Y2XfgZSv3-PqtQerfXsZ-s4owdjz6awCKSCDu4_L8TfAt',
#      'width': 1536}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 827,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#      'photo_reference': 'Aap_uEC4UvB7Hr-5ps4caAlqQEe-j52EV65NMgqrJyMpBmZMEsit-rhcmYsi8beEhsceU41V_ynEw9m3rcCYkdrFe2BCO5iCgnwfZj9fzFXjFB6qHHasRDG98t7YqWj8jlONPcd0U6RVtJd6h08BgIOgh9AG6dhwbMZwT4p-KLDxQFYA0y4v',
#      'width': 3000}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 195,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEAxxGYD49CKPv4bKfKvix_zIcM5xvt5UxJCxdwnsii3fALkdTtNxqJGUvu_wnD8eSWNaML0bLzTb0cYFOfk0rGcE_e__I4VqokbQog4K6O8x-udx4aWtYt7J4R2yTgCZ7-qh_gcaV0Izhi-8h-Kxz3sESzNJZSp1cgdHxsmD3dO_zkF',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 381,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731374802915,
#       'lng': 2.346059980291502},
#      'southwest': {'lat': 48.8704395197085, 'lng': 2.343362019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113098608949799179620">Chrystelle Baudry</a>'],
#      'photo_reference': 'Aap_uEA8HO7WkrGoI1JCltIn5tn15MGVXW6mV56gxPLJzXH2EOpa_8z16DbjOdfIoLMCEvVLBw-4tqttQxLuvIDHtn45fkkeH7GaSbMRrC6WKAg5klL3084sOd-TFDbwfnLIao-exPRlApxBwWm-SqkHgvNfGlapk6cAHLKn2TFpzJ8fFXAS',
#      'width': 3840}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.2,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 369,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEA6rQrOYoXU1RC4Glajvcugjs_0e6Pp2FQNTMueDtDRbbOU-LX390Lb6NH4Dq8tllyf354TrBn9VkvcNdQIMm2LUyvBrivEluWlt3Pnz3n9qXsG9zvCOguGbkFUH9QM2tXRJifbrPMUrvpj8wlBP6TIJQY17hz7_kwZZu9TH3g7kDzN',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 437,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8642974, 'lng': 2.3308142},
#     'viewport': {'northeast': {'lat': 48.8655789302915,
#       'lng': 2.332153980291502},
#      'southwest': {'lat': 48.8628809697085, 'lng': 2.329456019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uEDrixGPwAMZ-nP0R-MJbbkNPrPBPje4FBPlWsxZDSKyojcRzOQkV5KnayYPlVYhjH8xDFib8otrpgRxO9bExsGUjlxJuqf-wOsWSsJWIDKLA9HrP8mOL_MW8AiEBdToZKzaqMcq4-lCBkxAgEsHVe-7liTlwJk7qVLnScGRydYD6Wsp',
#      'width': 600}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1075,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uECehwgPSP1jf3T7pjgyiFcyNL7tIDYN4KuxqcRpUsaYH2blwCXoQnqwYd2Eopqzy9l_LwTxONya4yngEaQBZsmw5Z31oFav2U5vbu2KiGGr_vXe0ITJ7sBzkYOJKxrNx7B02ykqndncc0ZEidjndf-cl7KYXqxKsuBvB_qstyWgJT10',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.7,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 140,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia Hentze</a>'],
#      'photo_reference': 'Aap_uEAKDNk7yNmMt4-bi4Oh8DiVEXfck1ql1AYi9qbvHOMDdVf_XTu1tGdZxQTvHWoQ8Zx4mIF5JJyqLJrnMezcQ5fuS9Zjsu9Dm2XW2EFSRnNaWRxOZQajifJ_yDiIkw1hwirs4Z9qd3WB5m54LvXDyT1LFPlnUto3q76S1aPnXGrpAps6',
#      'width': 3024}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 145,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uECirwCQPIZBqDLWKnf8mRL58mNcb5Qag_AWfMUwUdZwzf2szU4FwEc4xBtXRU--iw7LwqnZa0MpRZpEBQw_90Gz4R6utVfPRmuELXRiIr-1J7DDt4Y30RoEDSOMc-E8eholqsHUpVBOiyIk2v8HYXZDRxi62W6PJxbqhyVfkmRE2mQ0',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 330,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#     'viewport': {'northeast': {'lat': 48.8512737302915,
#       'lng': 2.347507380291502},
#      'southwest': {'lat': 48.8485757697085, 'lng': 2.344809419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108547915404801536469">Jp Homma</a>'],
#      'photo_reference': 'Aap_uEDeBPECLSJkDZ_JCD5lsEwOs5NH3nSpUHdGUMRXJhNaPijB_TEBIRz6qvPs6e0qBe-LIzTWGHNhEz3xhzoXV6ZAsjeMbO1dyVuEcVuL1SzWBZy8tXdkuWq5o_SNqbuI2rCBscadGbUNzCX4i3YQ-BOCkMhYzefeEdx7MqCrwnfNZmXq',
#      'width': 4608}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 280,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3568,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uECYBjs3lueW5qBCXSPyOisoi6I4JxRCUdqWRSawErhHL0Grnc52JWmAO4EmmSZvUjUnr2rY0ViXiCa_-OkcesYQg9D8EZGv90Yu6bcKlUqAajD_hNS8gBphlrvRqBaxAYB3NcVpy71hapolyACAckxsT6gyvjXaLQIR8dJ_m5_g_bxZ',
#      'width': 5353}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 292,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uECFJhMLBstUJ6L7by7Wg9n8y4hk0jdN7N8W1-S2UOpGqMMiNs6scH0i2Xyc-XMFmvS6uHpKmlypWHzr5jCJNsnmV8gnKsqWiIV-Nq96TK8N_CsKVODpwY4k1EjIYTmUNDGcUh1hZ3ByfWOsHPbSBsQ8hMDVWJwqI6J080VMYJLESNxk',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
hotels['results'][0]['name']
# Out:
# 'Hôtel Duo'

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
        print('Hotel for ' + hotel_df.loc[index, 'City'] + ' is: ' + hotel_df.loc[index, "Hotel Name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel for Maryville is: Holiday Inn Express & Suites Alcoa (Knoxville Airport), an IHG Hotel
# Hotel for Kloulklubed is: Storyboard Beach Resort
# Hotel for Puerto Ayora is: Finch Bay Galapagos Hotel
# Hotel for Kuala Lipis is: Lipis Centrepoint Hotel
# Hotel for Atuona is: Villa Enata
# Hotel for Victoria is: Mini Hotel Central
# Hotel for Fukue is: Goto Guesthouse Utojuku & SA Car Rental
# Hotel for Avarua is: Paradise Inn
# Hotel not found... skipping.
# Hotel for Faanui is: Bora-Bora Pearl Beach Resort & Spa
# Hotel not found... skipping.
# Hotel for Kapaa is: Sheraton Kauai Coconut Beach Resort
# Hotel for Qui Nhon is: Hoang Yen Canary Hotel
# Hotel for Lompoc is: Holiday Inn Express Lompoc, an IHG Hotel
# Hotel for Neyyattinkara is: P.W.D. Rest House
# Hotel for Hithadhoo is: Scoop Guest House
# Hotel for Sorong is: waigo splash hotel
# Hotel for Jalu is: صاحبة الفخامة
# Hotel for Wukari is: Elimtop
# Hotel for Karratha is: ibis Styles Karratha
# Hotel for Cayenne is: Hôtel Le Dronmi
# Hotel for Port Blair is: Welcomhotel By ITC Hotels, Bay Island, Port Blair
# Hotel for Damietta is: SULIMAN INN
# Hotel for Padang is: Mercure Padang
# Hotel for Estelle is: Boomtown Casino & Hotel New Orleans
# Hotel for Mandera is: Kornesh Hotel and Lodging
# Hotel for Tezu is: Circuit House
# Hotel for Khunti is: JD
# Hotel for Vieux-Habitants is: Gîtes Dardanelle
# Hotel for Kavieng is: Nusa Island Retreat
# Hotel for Buala is: Maringe Lagoon Lodge
# Hotel for Koumra is: Yamtoide house koumra
# Hotel for Makakilo City is: Marriott's Ko Olina Beach Club
# Hotel for Sechura is: Hospedaje Costa Bella
# Hotel for Daru is: Daru Lodge
# Hotel for Itarema is: Sea Lounge! Bar, Club & Restaurant
# Hotel for Mersing is: Timotel Hotel
# Hotel for Salinopolis is: Salinas Park Resort Maçarico AP101
# Hotel for Nabire is: Hotel Nusantara Nabire
# Hotel for Sur is: Sur Plaza Hotel
# Hotel for Kita is: Hôtel Chat Rouge
# Hotel for Kattivakkam is: Euronova Freezer
# Hotel for Erzin is: Artemis Otel
# Hotel for San Cristobal is: Posada Villaven C.A.
# Hotel for Ahuimanu is: Paradise Bay Resort
# Hotel for Kandrian is: Kandrian Station
# Hotel for Sao Filipe is: Hotel Xaguate
# Hotel for Bengkulu is: Grage Hotel Bengkulu
# Hotel for Tiffin is: Holiday Inn Express Tiffin, an IHG Hotel
# Hotel for Lorengau is: Lorengau Harbourside Hotel
# Hotel for Axim is: Axim Beach Resort And Spa
# Hotel for Nishihara is: Minshuku Agaihama
# Hotel for Harper is: Screensaver
# Hotel not found... skipping.
# Hotel for Springfield is: University Plaza Hotel & Convention Center
# Hotel for San Andres is: Hotel Arena Blanca
# Hotel for Poplar Bluff is: Holiday Inn Poplar Bluff
# Hotel for Kalyani is: Hotel Regal Star
# Hotel for West Bay is: Calypso Cove
# Hotel for Omboue is: Hotel Olako
# Hotel for Georgetown is: Cititel Penang
# Hotel for Langsa is: OYO 2964 Hotel Ridho
# Hotel for Yanam is: The Regency Hotel
# Hotel for Mporokoso is: Government Guest House
# Hotel for Cabedelo is: Hotel Pigalle
# Hotel for Tallahassee is: Four Points by Sheraton Tallahassee Downtown
# Hotel for Butaritari is: Isles Sunset Lodge
# Hotel for Biak is: Penginapan Kim
# Hotel for San Patricio is: Motel 6 Sinton, TX
# Hotel for Wewak is: In Wewak Boutique Hotel
# Hotel not found... skipping.
# Hotel for Marrakesh is: Novotel Marrakech Hivernage
# Hotel for Zhuhai is: Nanyang Seascape Hotel Zhuhai Hotel
# Hotel for Houma is: Courtyard by Marriott Houma
# Hotel for Tabora is: Barcelona Lodge
# Hotel for Morro Agudo is: Hotel Morro Agudo
# Hotel for Naze is: オーベルジュ・アガルイ
# Hotel for Kununurra is: Hotel Kununurra
# Hotel for Puerto Leguizamo is: la casona de juancho
# Hotel for Barabai is: HOTEL BOURAQ INDAH PERMAI
# Hotel for Asyut is: Florence Hotel Assiut
# Hotel for Itoman is: Southern Beach Hotel & Resort Okinawa
# Hotel for Gat is: OlusHome
# Hotel for Reconquista is: Grand Hotel
# Hotel for Mount Pleasant is: Best Western Patriots Point
# Hotel for Nouadhibou is: El Medina
# Hotel for Carutapera is: Lidera
# Hotel for Dakar is: Redface Studios Meublés
# Hotel for Namatanai is: Seagulls Inn Namatani
# Hotel for Meulaboh is: Kost Pria
# Hotel for Touros is: INN NEW HORIZON
# Hotel for Mecca is: Makkah Clock Royal Tower, A Fairmont Hotel
# Hotel for Hondo is: ホテル河丁
# Hotel for Xai-Xai is: Complexo da Familia
# Hotel for North Platte is: Holiday Inn Express & Suites North Platte, an IHG Hotel
# Hotel for Miri is: Mega Hotel, Miri
# Hotel for Sompeta is: Netaji's Home
# Hotel for Anakapalle is: Satya Lodge
# Hotel for Elat is: Club Hotel Eilat
# Hotel for Salalah is: HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# Hotel for Mana is: LE SAMANA
# Hotel not found... skipping.
# Hotel for Keti Bandar is: Haji laloo memon house
# Hotel for Bouna is: Hotel Reserve
# Hotel for Porto Novo is: Tour Eiffel Hotel Benin
# Hotel for Kalianget is: Pesanggrahan Garam
# Hotel for Luganville is: The Espiritu Hotel
# Hotel for Palu is: Hotel Santika Palu
# Hotel for Phalaborwa is: Bothabelo Bed and Breakfast
# Hotel for Parana is: Howard Johnson by Wyndham Plaza Hotel Mayorazgo
# Hotel for Ayame is: Hotel Bossan
# Hotel for Acarau is: castelo pizzaria
# Hotel for Port Keats is: TDC Village (Hundred Man Camp)
# Hotel for Luanda is: Hotel Fórum
# Hotel for Marsh Harbour is: Abaco Beach Resort
# Hotel for Bilma is: Expeditions Ténére voyages
# Hotel for Phangnga is: Sunimit Mansion
# Hotel for Calama is: Diego De Almagro Calama
# Hotel for Wilmington is: Hotel Ballast Wilmington, Tapestry Collection by Hilton
# Hotel for Dickinson is: Hampton Inn & Suites Houston/League City
# Hotel for Kot Diji is: Heritage Park, Restaurant & Guesthouse Kotdiji
# Hotel for Puerto El Triunfo is: Hotel Jardin
# Hotel for Guerrero Negro is: Casa Laguna, Bed & Breakfast
# Hotel for Santa Rosa is: Erlyn’s Sta Rosa City Home
# Hotel for Dullewala is: Sajid fruit shop
# Hotel for Praia is: LT Aparthotel
# Hotel for Kahului is: Maui Seaside Hotel
# Hotel for Ninghai is: Kaiyuan New Century Hotel
# Hotel for Destin is: Inn On Destin Harbor-Ascend Hotel Collection
# Hotel for Kavaratti is: Hotels in Lakshadweep Islands
# Hotel for Tayoltita is: Hotel Rivera Tayoltita
# Hotel for Quang Ngai is: Central Hotel
# Hotel for Bathsheba is: Atlantis Hotel
# Hotel for Eyl is: Amiin Hotel
# Hotel for Manggar is: Guest Hotel
# Hotel for Caraballeda is: Hotel 15 Letras
# Hotel for Ducheng is: Xinyongguang Hotel
# Hotel for Xuddur is: Banjanay Hotel
# Hotel for Santa Fe is: Conquistador Hotel
# Hotel for Ishigaki is: Hotel Peace Land Ishigakijima
# Hotel for Chiriguana is: Zapatosa Red Turística
# Hotel for Puerto Escondido is: Aldea del Bazar Hotel and Spa
# Hotel for Buraydah is: فندق راحة السلام
# Hotel for Mogadishu is: Hotel Juba
# Hotel for Chalakudi is: Hotel Sidhartha Luxury Business Class Hotel 4 STAR
# Hotel for Nanakuli is: Camp Pālehua
# Hotel for Bairiki is: Tarawa Boutique Hotel
# Hotel for Coruripe is: Pousada e Hotel Litoral Sul
# Hotel for Kupang is: Hotel On The Rock by Prasanthi
# Hotel for Malanje is: Malanje Hotel
# Hotel for Wajid is: xamdihotelresturant114
# Hotel for Zambezi is: Royal Kutachika Lodge
# Hotel for Paraiso is: Rinconcito Verde
# Hotel for Saint Anthony is: Holiday Inn Express Roseville-St. Paul, an IHG Hotel
# Hotel for Carlsbad is: Carlsbad Inn Beach Resort
# Hotel for Tautira is: Pension Oaoa
# Hotel for Buchanan is: Kamaneahn Hotel Inc
# Hotel not found... skipping.
# Hotel for Sarangani is: Ballistic Islet
# Hotel for Vega De Alatorre is: El Polo Norte
# Hotel for Safaga is: Lamar Resort Abu Soma
# Hotel for Kontagora is: Queens Guest Inn
# Hotel for Maragogi is: Salinas do Maragogi All Inclusive Resort
# Hotel for Tual is: Grand Vilia Hotel
# Hotel for Mahajanga is: Restaurant Greedy Coco Lodge Majunga
# Hotel for Najran is: محمد هادي ال فطيح
# Hotel for Pathein is: New Pammawaddy Hotel
# Hotel for Fare is: Maitai Lapita Village Huahine
# Hotel for Arang is: Hotel Kunwar Shree
# Hotel for Upata is: Posada Villa Nela
# Hotel for Mitsamiouli is: Foyer ADM
# Hotel not found... skipping.
# Hotel for Umm Lajj is: Moon light Furnished Units
# Hotel for Naliya is: jadeja jayendrasinh
# Hotel for Oussouye is: Auberge du Routard
# Hotel for Ambon is: Swiss-Belhotel Ambon
# Hotel for Ouagadougou is: Centrale Hotel

# %%
hotel_df.head()
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 1      Maryville      US     80.20  35.7565  -83.9705
# 4    Kloulklubed      PW     83.28   7.0419  134.2556
# 8   Puerto Ayora      EC     76.96  -0.7393  -90.3518
# 10   Kuala Lipis      MY     75.90   4.1842  102.0468
# 12        Atuona      PF     77.97  -9.8000 -139.0333
#
#                                            Hotel Name
# 1   Holiday Inn Express & Suites Alcoa (Knoxville ...
# 4                             Storyboard Beach Resort
# 8                           Finch Bay Galapagos Hotel
# 10                            Lipis Centrepoint Hotel
# 12                                        Villa Enata

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.6)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
