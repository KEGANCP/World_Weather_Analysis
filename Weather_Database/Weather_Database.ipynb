# %%
# %matplotlib inline

# %%
#add Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import timeit
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
#Empty city_data list
city_data = []
print('Log Start')
print("-----------------------------")

#create counters
record_count = 1
set_count = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather": weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Log Start
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | syracuse
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | alice springs
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | viesca
# Processing Record 11 of Set 1 | takoradi
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | khandyga
# Processing Record 18 of Set 1 | bathsheba
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | nabire
# Processing Record 23 of Set 1 | lourdes
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | bell ville
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | kidal
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | livingston
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | sinnamary
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | fort portal
# Processing Record 41 of Set 1 | lysyye gory
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | gorontalo
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | isangel
# Processing Record 50 of Set 1 | yulara
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 2 | kupang
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | sisimiut
# Processing Record 6 of Set 2 | ostrovnoy
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | narsaq
# Processing Record 9 of Set 2 | xichang
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | calabar
# Processing Record 15 of Set 2 | chilliwack
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | nuevo laredo
# Processing Record 18 of Set 2 | grand gaube
# Processing Record 19 of Set 2 | anuradhapura
# Processing Record 20 of Set 2 | borba
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | port hardy
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | el dorado
# Processing Record 25 of Set 2 | kembe
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | kambove
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | saint-augustin
# Processing Record 32 of Set 2 | galle
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | campo formoso
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | dingle
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | moose factory
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | alofi
# Processing Record 41 of Set 2 | grande-riviere
# City not found. Skipping...
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | zhangye
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | chute-aux-outardes
# Processing Record 46 of Set 2 | sulangan
# Processing Record 47 of Set 2 | mollendo
# Processing Record 48 of Set 2 | atherton
# Processing Record 49 of Set 2 | saint-francois
# Processing Record 50 of Set 2 | male
# Processing Record 1 of Set 3 | ambunti
# Processing Record 2 of Set 3 | maumere
# Processing Record 3 of Set 3 | shubarshi
# Processing Record 4 of Set 3 | fort nelson
# Processing Record 5 of Set 3 | gdansk
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | porto walter
# Processing Record 8 of Set 3 | olafsvik
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | maragogi
# Processing Record 11 of Set 3 | maymyo
# Processing Record 12 of Set 3 | badvel
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | kalabo
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | aitape
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 22 of Set 3 | am timan
# Processing Record 23 of Set 3 | emerald
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 3 | misratah
# Processing Record 28 of Set 3 | tangzhai
# Processing Record 29 of Set 3 | angola
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | coihueco
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 35 of Set 3 | seoul
# Processing Record 36 of Set 3 | atikokan
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | nuqui
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | eureka
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | saint-georges
# Processing Record 44 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | pudozh
# Processing Record 47 of Set 3 | yar-sale
# Processing Record 48 of Set 3 | tromso
# Processing Record 49 of Set 3 | formiga
# Processing Record 50 of Set 3 | kununurra
# Processing Record 1 of Set 4 | castro
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | sistranda
# Processing Record 4 of Set 4 | matara
# Processing Record 5 of Set 4 | stornoway
# Processing Record 6 of Set 4 | havoysund
# Processing Record 7 of Set 4 | yeppoon
# Processing Record 8 of Set 4 | zeya
# Processing Record 9 of Set 4 | pangai
# Processing Record 10 of Set 4 | bogorodskoye
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | puerto madryn
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 15 of Set 4 | luleburgaz
# Processing Record 16 of Set 4 | zarubino
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | turka
# Processing Record 21 of Set 4 | diapaga
# Processing Record 22 of Set 4 | san jose
# Processing Record 23 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | bredasdorp
# Processing Record 27 of Set 4 | honiara
# Processing Record 28 of Set 4 | coihaique
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | praia da vitoria
# Processing Record 31 of Set 4 | portobelo
# Processing Record 32 of Set 4 | bulgan
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | suez
# Processing Record 35 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | cherskiy
# Processing Record 37 of Set 4 | mayo
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | farafangana
# Processing Record 40 of Set 4 | kashary
# Processing Record 41 of Set 4 | kampong thum
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | taltal
# Processing Record 44 of Set 4 | zacatepec
# Processing Record 45 of Set 4 | yamada
# Processing Record 46 of Set 4 | vilhena
# Processing Record 47 of Set 4 | loralai
# Processing Record 48 of Set 4 | grimstad
# Processing Record 49 of Set 4 | la belgica
# Processing Record 50 of Set 4 | lappeenranta
# Processing Record 1 of Set 5 | timra
# Processing Record 2 of Set 5 | sagua la grande
# Processing Record 3 of Set 5 | komsomolskiy
# Processing Record 4 of Set 5 | hualmay
# Processing Record 5 of Set 5 | la serena
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | buin
# Processing Record 9 of Set 5 | phan thiet
# Processing Record 10 of Set 5 | constitucion
# Processing Record 11 of Set 5 | sainte-maxime
# Processing Record 12 of Set 5 | obigarm
# Processing Record 13 of Set 5 | jiexiu
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | iquique
# Processing Record 16 of Set 5 | nangan
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | wang saphung
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | kandrian
# Processing Record 25 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 5 | sur
# Processing Record 27 of Set 5 | ishigaki
# Processing Record 28 of Set 5 | itarema
# Processing Record 29 of Set 5 | charters towers
# Processing Record 30 of Set 5 | mosjoen
# Processing Record 31 of Set 5 | yumen
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 5 | tsabong
# Processing Record 36 of Set 5 | sarangani
# Processing Record 37 of Set 5 | road town
# Processing Record 38 of Set 5 | plaza de caisan
# Processing Record 39 of Set 5 | prainha
# Processing Record 40 of Set 5 | huaral
# Processing Record 41 of Set 5 | vangaindrano
# Processing Record 42 of Set 5 | chara
# Processing Record 43 of Set 5 | boyolangu
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 5 | cairns
# Processing Record 47 of Set 5 | samarai
# Processing Record 48 of Set 5 | butaritari
# Processing Record 49 of Set 5 | san matias
# Processing Record 50 of Set 5 | port hedland
# Processing Record 1 of Set 6 | homberg
# Processing Record 2 of Set 6 | qandala
# Processing Record 3 of Set 6 | chililabombwe
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | dunedin
# Processing Record 7 of Set 6 | meulaboh
# Processing Record 8 of Set 6 | severo-yeniseyskiy
# Processing Record 9 of Set 6 | merauke
# Processing Record 10 of Set 6 | arman
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | ulaangom
# Processing Record 13 of Set 6 | kamenka
# Processing Record 14 of Set 6 | deori khas
# Processing Record 15 of Set 6 | dzhebariki-khaya
# Processing Record 16 of Set 6 | ismailia
# Processing Record 17 of Set 6 | llangefni
# Processing Record 18 of Set 6 | soyo
# Processing Record 19 of Set 6 | darhan
# Processing Record 20 of Set 6 | qaanaaq
# Processing Record 21 of Set 6 | chengde
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | pangody
# Processing Record 24 of Set 6 | jahanabad
# Processing Record 25 of Set 6 | concepcion del oro
# Processing Record 26 of Set 6 | wuda
# Processing Record 27 of Set 6 | marrakesh
# Processing Record 28 of Set 6 | scottsbluff
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | esperance
# Processing Record 31 of Set 6 | suntar
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | byron bay
# Processing Record 34 of Set 6 | ganzhou
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | riyadh
# Processing Record 37 of Set 6 | shingu
# Processing Record 38 of Set 6 | viedma
# Processing Record 39 of Set 6 | padang
# Processing Record 40 of Set 6 | linxia
# Processing Record 41 of Set 6 | pringsewu
# Processing Record 42 of Set 6 | necochea
# Processing Record 43 of Set 6 | nuevo progreso
# Processing Record 44 of Set 6 | lakatoro
# Processing Record 45 of Set 6 | edgewater
# Processing Record 46 of Set 6 | high prairie
# Processing Record 47 of Set 6 | alyangula
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | correntina
# Processing Record 50 of Set 6 | fairbanks
# Processing Record 1 of Set 7 | abha
# Processing Record 2 of Set 7 | crestview
# Processing Record 3 of Set 7 | sterling
# Processing Record 4 of Set 7 | beyneu
# Processing Record 5 of Set 7 | johvi
# Processing Record 6 of Set 7 | huilong
# Processing Record 7 of Set 7 | ponta delgada
# Processing Record 8 of Set 7 | naberera
# Processing Record 9 of Set 7 | buloh kasap
# Processing Record 10 of Set 7 | fort-shevchenko
# Processing Record 11 of Set 7 | angra
# City not found. Skipping...
# Processing Record 12 of Set 7 | sladkovo
# Processing Record 13 of Set 7 | tabuk
# Processing Record 14 of Set 7 | san juan
# Processing Record 15 of Set 7 | zhezkazgan
# Processing Record 16 of Set 7 | dalvik
# Processing Record 17 of Set 7 | bilibino
# Processing Record 18 of Set 7 | beohari
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | sao sebastiao
# Processing Record 21 of Set 7 | turinsk
# Processing Record 22 of Set 7 | imbituba
# Processing Record 23 of Set 7 | jiuquan
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 25 of Set 7 | ambilobe
# Processing Record 26 of Set 7 | bintulu
# Processing Record 27 of Set 7 | wajima
# Processing Record 28 of Set 7 | severo-kurilsk
# Processing Record 29 of Set 7 | coquimbo
# Processing Record 30 of Set 7 | lata
# Processing Record 31 of Set 7 | shwebo
# Processing Record 32 of Set 7 | kushima
# Processing Record 33 of Set 7 | hofn
# Processing Record 34 of Set 7 | la sarre
# Processing Record 35 of Set 7 | asyut
# Processing Record 36 of Set 7 | wanning
# Processing Record 37 of Set 7 | soure
# Processing Record 38 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 7 | nola
# Processing Record 40 of Set 7 | pochutla
# Processing Record 41 of Set 7 | roanoke rapids
# Processing Record 42 of Set 7 | kjollefjord
# Processing Record 43 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 45 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 7 | cabra
# Processing Record 47 of Set 7 | balykshi
# Processing Record 48 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 7 | guerrero negro
# Processing Record 50 of Set 7 | ixtapa
# Processing Record 1 of Set 8 | zhigansk
# Processing Record 2 of Set 8 | la paz
# Processing Record 3 of Set 8 | pitimbu
# Processing Record 4 of Set 8 | salalah
# Processing Record 5 of Set 8 | torrevieja
# Processing Record 6 of Set 8 | saint-gaudens
# Processing Record 7 of Set 8 | fereydun kenar
# Processing Record 8 of Set 8 | norman wells
# Processing Record 9 of Set 8 | sao miguel do araguaia
# Processing Record 10 of Set 8 | imeni poliny osipenko
# Processing Record 11 of Set 8 | kamaishi
# Processing Record 12 of Set 8 | betsiamites
# Processing Record 13 of Set 8 | richards bay
# Processing Record 14 of Set 8 | liwale
# Processing Record 15 of Set 8 | dikson
# Processing Record 16 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 8 | mingaora
# Processing Record 18 of Set 8 | faratsiho
# Processing Record 19 of Set 8 | arboledas
# Processing Record 20 of Set 8 | cheremukhovo
# Processing Record 21 of Set 8 | tarko-sale
# Processing Record 22 of Set 8 | agadez
# Processing Record 23 of Set 8 | mantua
# Processing Record 24 of Set 8 | kashi
# Processing Record 25 of Set 8 | bereda
# Processing Record 26 of Set 8 | louviers
# Processing Record 27 of Set 8 | kanniyakumari
# Processing Record 28 of Set 8 | matamoros
# Processing Record 29 of Set 8 | paita
# Processing Record 30 of Set 8 | sunbury
# Processing Record 31 of Set 8 | springbok
# Processing Record 32 of Set 8 | banda aceh
# Processing Record 33 of Set 8 | ahipara
# Processing Record 34 of Set 8 | tizapan el alto
# Processing Record 35 of Set 8 | ilulissat
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | olot
# Processing Record 38 of Set 8 | naryan-mar
# Processing Record 39 of Set 8 | caramay
# Processing Record 40 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 8 | synya
# Processing Record 42 of Set 8 | wajir
# Processing Record 43 of Set 8 | saint anthony
# Processing Record 44 of Set 8 | port blair
# Processing Record 45 of Set 8 | nanchang
# Processing Record 46 of Set 8 | elizabeth city
# Processing Record 47 of Set 8 | poronaysk
# Processing Record 48 of Set 8 | ulcinj
# Processing Record 49 of Set 8 | camacha
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 9 | san pedro
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | inhambane
# Processing Record 5 of Set 9 | santa cruz de tenerife
# Processing Record 6 of Set 9 | hami
# Processing Record 7 of Set 9 | mikhaylovskoye
# Processing Record 8 of Set 9 | dogondoutchi
# Processing Record 9 of Set 9 | ariquemes
# Processing Record 10 of Set 9 | novobiryusinskiy
# Processing Record 11 of Set 9 | barra do garcas
# Processing Record 12 of Set 9 | omsukchan
# Processing Record 13 of Set 9 | teya
# Processing Record 14 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 15 of Set 9 | maceio
# Processing Record 16 of Set 9 | szamotuly
# Processing Record 17 of Set 9 | tamworth
# Processing Record 18 of Set 9 | bayir
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | manokwari
# Processing Record 21 of Set 9 | jiancheng
# Processing Record 22 of Set 9 | fernan-nunez
# Processing Record 23 of Set 9 | santa marta
# Processing Record 24 of Set 9 | aksarka
# Processing Record 25 of Set 9 | craig
# Processing Record 26 of Set 9 | tambovka
# Processing Record 27 of Set 9 | novyy urengoy
# Processing Record 28 of Set 9 | malko tarnovo
# Processing Record 29 of Set 9 | camopi
# Processing Record 30 of Set 9 | virden
# Processing Record 31 of Set 9 | mount gambier
# Processing Record 32 of Set 9 | banswada
# Processing Record 33 of Set 9 | katsuura
# Processing Record 34 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 9 | pak chong
# Processing Record 36 of Set 9 | pecos
# Processing Record 37 of Set 9 | callaway
# Processing Record 38 of Set 9 | sungaipenuh
# Processing Record 39 of Set 9 | vestmannaeyjar
# Processing Record 40 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 9 | ust-nera
# Processing Record 42 of Set 9 | kayerkan
# Processing Record 43 of Set 9 | la ronge
# Processing Record 44 of Set 9 | novovarshavka
# Processing Record 45 of Set 9 | nome
# Processing Record 46 of Set 9 | kurumkan
# Processing Record 47 of Set 9 | kampot
# Processing Record 48 of Set 9 | tilichiki
# Processing Record 49 of Set 9 | santa maria
# Processing Record 50 of Set 9 | praya
# Processing Record 1 of Set 10 | kuching
# Processing Record 2 of Set 10 | wainwright
# Processing Record 3 of Set 10 | mazagao
# Processing Record 4 of Set 10 | marsaxlokk
# Processing Record 5 of Set 10 | pauini
# Processing Record 6 of Set 10 | egvekinot
# Processing Record 7 of Set 10 | kangasala
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | nirmal
# Processing Record 10 of Set 10 | xunchang
# Processing Record 11 of Set 10 | maxixe
# Processing Record 12 of Set 10 | north fort myers
# Processing Record 13 of Set 10 | mehamn
# Processing Record 14 of Set 10 | khani
# Processing Record 15 of Set 10 | fare
# Processing Record 16 of Set 10 | dese
# Processing Record 17 of Set 10 | safford
# Processing Record 18 of Set 10 | san quintin
# Processing Record 19 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 20 of Set 10 | pevek
# Processing Record 21 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 22 of Set 10 | saquena
# Processing Record 23 of Set 10 | siuna
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 10 | henties bay
# Processing Record 27 of Set 10 | kincardine
# Processing Record 28 of Set 10 | bandarbeyla
# Processing Record 29 of Set 10 | arlit
# Processing Record 30 of Set 10 | nishihara
# Processing Record 31 of Set 10 | coahuayana
# Processing Record 32 of Set 10 | derzhavinsk
# Processing Record 33 of Set 10 | sayyan
# Processing Record 34 of Set 10 | gurupa
# Processing Record 35 of Set 10 | otradnoye
# Processing Record 36 of Set 10 | los llanos de aridane
# Processing Record 37 of Set 10 | codrington
# Processing Record 38 of Set 10 | neuquen
# Processing Record 39 of Set 10 | havelock
# Processing Record 40 of Set 10 | champerico
# Processing Record 41 of Set 10 | vila velha
# Processing Record 42 of Set 10 | conde
# Processing Record 43 of Set 10 | howard springs
# Processing Record 44 of Set 10 | jawhar
# Processing Record 45 of Set 10 | sehithwa
# Processing Record 46 of Set 10 | ust-omchug
# Processing Record 47 of Set 10 | muskogee
# Processing Record 48 of Set 10 | vermilion
# Processing Record 49 of Set 10 | los algarrobos
# Processing Record 50 of Set 10 | mega
# Processing Record 1 of Set 11 | kokkola
# Processing Record 2 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 3 of Set 11 | russell
# Processing Record 4 of Set 11 | toktogul
# Processing Record 5 of Set 11 | mareeba
# Processing Record 6 of Set 11 | birao
# Processing Record 7 of Set 11 | lashio
# Processing Record 8 of Set 11 | muros
# Processing Record 9 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 11 | ostersund
# Processing Record 12 of Set 11 | boa vista
# Processing Record 13 of Set 11 | teahupoo
# Processing Record 14 of Set 11 | rawson
# Processing Record 15 of Set 11 | volodarskiy
# Processing Record 16 of Set 11 | havre
# Processing Record 17 of Set 11 | mae hong son
# Processing Record 18 of Set 11 | gardner
# Processing Record 19 of Set 11 | kayes
# Processing Record 20 of Set 11 | sechura
# Processing Record 21 of Set 11 | puerto escondido
# Processing Record 22 of Set 11 | bergen
# Processing Record 23 of Set 11 | tagusao
# Processing Record 24 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 25 of Set 11 | ardmore
# Processing Record 26 of Set 11 | solnechnyy
# Processing Record 27 of Set 11 | santiago
# Processing Record 28 of Set 11 | alta floresta
# Processing Record 29 of Set 11 | oranjemund
# Processing Record 30 of Set 11 | abnub
# Processing Record 31 of Set 11 | poum
# Processing Record 32 of Set 11 | tura
# Processing Record 33 of Set 11 | killarney
# Processing Record 34 of Set 11 | wewak
# Processing Record 35 of Set 11 | nieves
# Processing Record 36 of Set 11 | bodden town
# Processing Record 37 of Set 11 | perur
# Processing Record 38 of Set 11 | guilin
# Processing Record 39 of Set 11 | nouadhibou
# Processing Record 40 of Set 11 | manitouwadge
# Processing Record 41 of Set 11 | tanda
# Processing Record 42 of Set 11 | dubrovnik
# Processing Record 43 of Set 11 | gritsovskiy
# Processing Record 44 of Set 11 | ajaccio
# Processing Record 45 of Set 11 | puerto ayacucho
# Processing Record 46 of Set 11 | staraya toropa
# Processing Record 47 of Set 11 | jalu
# Processing Record 48 of Set 11 | sena madureira
# Processing Record 49 of Set 11 | vostok
# Processing Record 50 of Set 11 | ucluelet
# Processing Record 1 of Set 12 | markala
# Processing Record 2 of Set 12 | liverpool
# Processing Record 3 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 12 | daru
# Processing Record 5 of Set 12 | porto novo
# Processing Record 6 of Set 12 | chicama
# Processing Record 7 of Set 12 | banfora
# Processing Record 8 of Set 12 | acarigua
# Processing Record 9 of Set 12 | avera
# Processing Record 10 of Set 12 | vila franca do campo
# Processing Record 11 of Set 12 | sucua
# Processing Record 12 of Set 12 | najran
# Processing Record 13 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 12 | the valley
# Processing Record 15 of Set 12 | sestri levante
# Processing Record 16 of Set 12 | lavrentiya
# Processing Record 17 of Set 12 | saint george
# Processing Record 18 of Set 12 | mayumba
# Processing Record 19 of Set 12 | yarmouth
# Processing Record 20 of Set 12 | bullhead city
# Processing Record 21 of Set 12 | kloulklubed
# Processing Record 22 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 12 | sambava
# Processing Record 24 of Set 12 | ngunguru
# Processing Record 25 of Set 12 | muli
# Processing Record 26 of Set 12 | chapais
# Processing Record 27 of Set 12 | noumea
# Processing Record 28 of Set 12 | antigonish
# Processing Record 29 of Set 12 | gonbad-e qabus
# Processing Record 30 of Set 12 | barao de melgaco
# Processing Record 31 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 12 | humen
# Processing Record 33 of Set 12 | banjar
# Processing Record 34 of Set 12 | touros
# Processing Record 35 of Set 12 | longhua
# Processing Record 36 of Set 12 | chulym
# Processing Record 37 of Set 12 | gat
# Processing Record 38 of Set 12 | obo
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | sri aman
# Processing Record 41 of Set 12 | broken hill
# Processing Record 42 of Set 12 | antofagasta
# Processing Record 43 of Set 12 | flinders
# Processing Record 44 of Set 12 | cockburn town
# Processing Record 45 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 12 | macomer
# Processing Record 47 of Set 12 | dhidhdhoo
# Processing Record 48 of Set 12 | pemberton
# Processing Record 49 of Set 12 | susuman
# Processing Record 50 of Set 12 | stawell
# Processing Record 1 of Set 13 | rusape
# Processing Record 2 of Set 13 | manacapuru
# Processing Record 3 of Set 13 | korla
# Processing Record 4 of Set 13 | sabang
# Processing Record 5 of Set 13 | vung tau
# Processing Record 6 of Set 13 | okhotsk
# Processing Record 7 of Set 13 | wer
# Processing Record 8 of Set 13 | woodward
# Processing Record 9 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 13 | muisne
# Processing Record 11 of Set 13 | sanmenxia
# Processing Record 12 of Set 13 | maneadero
# Processing Record 13 of Set 13 | nawa
# Processing Record 14 of Set 13 | marzuq
# Processing Record 15 of Set 13 | maridi
# Processing Record 16 of Set 13 | sangmelima
# Processing Record 17 of Set 13 | bay saint louis
# Processing Record 18 of Set 13 | sanchor
# Processing Record 19 of Set 13 | staraya mayna
# Processing Record 20 of Set 13 | pemangkat
# Processing Record 21 of Set 13 | caloundra
# Processing Record 22 of Set 13 | afsin
# Processing Record 23 of Set 13 | faya
# Processing Record 24 of Set 13 | pacific grove
# Processing Record 25 of Set 13 | ossora
# Processing Record 26 of Set 13 | mosetse
# Processing Record 27 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 13 | ibra
# Processing Record 29 of Set 13 | san cristobal
# Processing Record 30 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 31 of Set 13 | haines junction
# Processing Record 32 of Set 13 | monroe
# Processing Record 33 of Set 13 | raudeberg
# Processing Record 34 of Set 13 | twentynine palms
# Processing Record 35 of Set 13 | angoche
# Processing Record 36 of Set 13 | canon city
# Processing Record 37 of Set 13 | millau
# Processing Record 38 of Set 13 | davila
# Processing Record 39 of Set 13 | usinsk
# Processing Record 40 of Set 13 | aswan
# Processing Record 41 of Set 13 | harper
# Processing Record 42 of Set 13 | itoman
# Processing Record 43 of Set 13 | rudbar
# Processing Record 44 of Set 13 | xining
# Processing Record 45 of Set 13 | moron
# Processing Record 46 of Set 13 | shieli
# Processing Record 47 of Set 13 | traverse city
# Processing Record 48 of Set 13 | yenagoa
# Processing Record 49 of Set 13 | te anau
# Processing Record 50 of Set 13 | kemijarvi
# Processing Record 1 of Set 14 | sorong
# Processing Record 2 of Set 14 | rafai
# Processing Record 3 of Set 14 | iracoubo
# Processing Record 4 of Set 14 | bayan
# Processing Record 5 of Set 14 | ellisras
# Processing Record 6 of Set 14 | sao paulo de olivenca
# Processing Record 7 of Set 14 | northam
# Processing Record 8 of Set 14 | thio
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | san jeronimo
# Processing Record 11 of Set 14 | roald
# Processing Record 12 of Set 14 | polovinnoye
# Processing Record 13 of Set 14 | dudinka
# Processing Record 14 of Set 14 | aksu
# Processing Record 15 of Set 14 | gweru
# Processing Record 16 of Set 14 | port-gentil
# Processing Record 17 of Set 14 | jardim
# Processing Record 18 of Set 14 | langham
# Processing Record 19 of Set 14 | bagn
# Processing Record 20 of Set 14 | qui nhon
# Processing Record 21 of Set 14 | grosseto
# Processing Record 22 of Set 14 | ransang
# Processing Record 23 of Set 14 | ligayan
# Processing Record 24 of Set 14 | palombara sabina
# Processing Record 25 of Set 14 | murray
# Processing Record 26 of Set 14 | kargasok
# Processing Record 27 of Set 14 | mushie
# Processing Record 28 of Set 14 | hirna
# Processing Record 29 of Set 14 | terrace bay
# Processing Record 30 of Set 14 | okato
# Processing Record 31 of Set 14 | sorland
# Processing Record 32 of Set 14 | gondanglegi
# Processing Record 33 of Set 14 | sitka
# Processing Record 34 of Set 14 | martapura
# Processing Record 35 of Set 14 | bitung
# Processing Record 36 of Set 14 | prieska
# Processing Record 37 of Set 14 | catemaco
# Processing Record 38 of Set 14 | hamilton
# Processing Record 39 of Set 14 | hambantota
# Processing Record 40 of Set 14 | lipin bor
# Processing Record 41 of Set 14 | yuancheng
# Processing Record 42 of Set 14 | vila
# Processing Record 43 of Set 14 | acapulco
# Processing Record 44 of Set 14 | dondo
# Processing Record 45 of Set 14 | laurel
# Processing Record 46 of Set 14 | naze
# Processing Record 47 of Set 14 | mazamet
# Processing Record 48 of Set 14 | murray bridge
# Processing Record 49 of Set 14 | noyabrsk
# Processing Record 50 of Set 14 | half moon bay
# Processing Record 1 of Set 15 | japura
# Processing Record 2 of Set 15 | beringovskiy
# Processing Record 3 of Set 15 | marathon
# Processing Record 4 of Set 15 | talcahuano
# Processing Record 5 of Set 15 | sioux lookout
# Processing Record 6 of Set 15 | varzelandia
# Processing Record 7 of Set 15 | sola
# Processing Record 8 of Set 15 | nyurba
# Processing Record 9 of Set 15 | prince george
# Processing Record 10 of Set 15 | lalsk
# Processing Record 11 of Set 15 | tatawin
# Processing Record 12 of Set 15 | finschhafen
# Processing Record 13 of Set 15 | teguldet
# Processing Record 14 of Set 15 | bar harbor
# Processing Record 15 of Set 15 | natal
# Processing Record 16 of Set 15 | zambrano
# Processing Record 17 of Set 15 | tyn nad vltavou
# Processing Record 18 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 15 | brandon
# Processing Record 20 of Set 15 | udachnyy
# Processing Record 21 of Set 15 | burnie
# Processing Record 22 of Set 15 | odweyne
# Processing Record 23 of Set 15 | sangar
# Processing Record 24 of Set 15 | portland
# Processing Record 25 of Set 15 | bonthe
# Processing Record 26 of Set 15 | natitingou
# Processing Record 27 of Set 15 | kaeo
# Processing Record 28 of Set 15 | plyussa
# Processing Record 29 of Set 15 | mtimbira
# Processing Record 30 of Set 15 | remanso
# Processing Record 31 of Set 15 | dwarka
# Processing Record 32 of Set 15 | boguchany
# Processing Record 33 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 15 | stokmarknes
# Processing Record 35 of Set 15 | fraga
# Processing Record 36 of Set 15 | copalillo
# Processing Record 37 of Set 15 | boundiali
# Processing Record 38 of Set 15 | nakatunguru
# Processing Record 39 of Set 15 | culpeper
# Processing Record 40 of Set 15 | jieshi
# Processing Record 41 of Set 15 | along
# Processing Record 42 of Set 15 | bunia
# Processing Record 43 of Set 15 | blythe
# Processing Record 44 of Set 15 | caravelas
# Processing Record 45 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 15 | tofield
# Processing Record 47 of Set 15 | nhulunbuy
# Processing Record 48 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 49 of Set 15 | komatipoort
# Processing Record 50 of Set 15 | roswell
# Processing Record 1 of Set 16 | tabou
# Processing Record 2 of Set 16 | macheta
# Processing Record 3 of Set 16 | sao joao da barra
# Processing Record 4 of Set 16 | buraydah
# Processing Record 5 of Set 16 | belyy yar
# Processing Record 6 of Set 16 | aden
# Processing Record 7 of Set 16 | sibolga
# Processing Record 8 of Set 16 | bababe
# City not found. Skipping...
# Processing Record 9 of Set 16 | veshenskaya
# Processing Record 10 of Set 16 | suzhou
# Processing Record 11 of Set 16 | husavik
# Processing Record 12 of Set 16 | comodoro rivadavia
# Processing Record 13 of Set 16 | tandalti
# Processing Record 14 of Set 16 | fonte boa
# Processing Record 15 of Set 16 | raseiniai
# Processing Record 16 of Set 16 | tibati
# Processing Record 17 of Set 16 | anadyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Set columns and preview
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0    Rikitea      PF  2021-10-09 20:38:30 -23.1203 -134.9692     74.34
# 1   Khatanga      RU  2021-10-09 20:42:39  71.9667  102.5000     17.64
# 2  Jamestown      US  2021-10-09 20:38:37  42.0970  -79.2353     68.52
# 3   Syracuse      IT  2021-10-09 20:42:40  37.0881   15.2792     65.89
# 4    Kavieng      PG  2021-10-09 20:42:40  -2.5744  150.7967     80.96
#
#    Humidity  Cloudiness  Wind Speed          Weather
# 0        82         100       17.94       light rain
# 1        96         100        1.23       light snow
# 2        87          90        8.99  overcast clouds
# 3        66          11        4.85       few clouds
# 4        80          89        8.61       light rain

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
